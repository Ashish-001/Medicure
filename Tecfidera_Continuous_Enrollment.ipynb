# %% [markdown]
# # TECFIDERA PATIENT CONTINUOUS ENROLLMENT
# This notebook pulls all the tecfidera drug patients from each source and checks the continuous enrollment for the patient.
# If patient is coming for refill before tecfidera dosage enddate then those patients will be assumed as continuous.
# Also, we have taken buffer of 60 days i.e if the patient is coming for refill before 60 days of drug completion/enddate then it will taken as continuous.

# %% [markdown]
# ## Set up Notebook
# The following step is essential to set up the notebook to do everything that you need. In the following code snow = Snowflake(role = 'RWD_SANDBOX',database='RWD_DB', schema='SANDBOX') the connections are set to hook up to the correct Role, database, and schema in snowfalke. Please note, these are just the default values and in future queries you can change the database and schema if the role hass access to them.

# %%
import qgrid
from datetime import timedelta, datetime
import math
import pandas as pd
from drg_connect import Snowflake

snow = Snowflake(role = 'PROJECT_BIOGEN_CUSTOM_ROLE',database='PROJECT_ANALYTICS',schema = 'BIOGEN')
engine = snow.engine

# %load_ext sql_magic
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine

# %% [markdown]
# ## Initializing standard variables
# These will be used throughout the project

# %%
buffer_60 = 60.0 
buffer_90 = 90.0 
buffer_120 = 120.0 
to_sql_array = lambda x: "({})".format(str(x)[1:-1])  # handy little function!
ndc_codes = to_sql_array(['64406000703','64406000501','64406000602'])
db = "PROJECT_ANALYTICS"
schema = "BIOGEN"
char_tbl = "Akmishra_TECFIDERA"
sith_ref_tbl = "PROJECT_BIOGEN_CUSTOM_ROLE"

# %% [markdown]
# ## Initial Data Pull
# Extrat data from all sources for the patients taking tecfidera drug

# %% [markdown]
# ### Pharmacy Data Pull (Condor+Osprey)

# %%
# %%read_sql
# --Pulling all the patients taking techfidera drugs from Condor+Osprey pharmacy table.
# CREATE TABLE {db}.{schema}.{char_tbl}_PHARMACY_V1  AS
#       SELECT 'PHARMACY'                              AS SOURCE
#              ,CLAIM_NUMBER
#              ,ENCRYPTED_KEY_1
#              ,ENCRYPTED_KEY_2
#              ,DATE_OF_BIRTH                         AS PATIENT_DOB
#              ,CASE WHEN PATIENT_GENDER_CODE  IN('1','M')
#                    THEN 'M'
#                    WHEN PATIENT_GENDER_CODE  IN('2','F')
#                    THEN 'F'
#                    ELSE 'X'
#               END                                   AS PATIENT_GENDER
#              ,PRODUCT_OR_SERVICE_ID                 AS DRUG_CODE
#              ,DATE_OF_SERVICE                       AS SERVICE_DATE
#              ,DAYS_SUPPLY
#
#        FROM  RWD_DB.RWD.RAVEN_PHARMACY
#        WHERE PRODUCT_OR_SERVICE_ID           IN {ndc_codes}
#          AND UPPER(RESPONSE_CODE)            = 'P'
# ;
# Out:
# Query started at 11:20:03 PM India Standard Time; Query executed in 32.96 m
#                                               status
# 0  Table AKMISHRA_PHARMACY_TECHFIDERA_V1 successf...

# %% [markdown]
# Count of patients and unique pharmacy claims from condor and osprey.  We have roughly 50k patients with over 1 million claims.

# %%
# %%read_sql
# --count of distinct patients and distinct claims from pharmacy data
#     SELECT COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_PHARMACY_V1
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
# Out:
# Query started at 11:53:05 PM India Standard Time; Query executed in 0.07 m
#    patient_count  claim_count
# 0          48344      1034754

# %% [markdown]
# There are three ndc codes for Tecfidera.  One is the starter pack and we need to figure out which is which

# %%
# %%read_sql
# --count of distinct patients and distinct claims for each ndc from pharmacy data
#     SELECT DRUG_CODE ,
#            COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_PHARMACY_V1
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
#     GROUP BY DRUG_CODE
# ;
# Out:
# Query started at 11:53:16 PM India Standard Time; Query executed in 0.20 m
#      drug_code  patient_count  claim_count
# 0  64406000602          44404       952248
# 1  64406000501           3554        16747
# 2  64406000703          26098        65759

# %% [markdown]
# ### Medical Data Pull (Raven + Osprey)
# Extract the ndc codes for Tecfidera from the raven procedures.  This is likely going to be a small number

# %%
# %%read_sql
# --Pulling all the patients taking techfidera drugs from RAVEN table.
# CREATE TABLE {db}.{schema}.{char_tbl}_MEDICAL_V1 AS
#       SELECT 'Medical'                                                                            AS SOURCE
#              ,CLAIM_NUMBER
#              ,ENCRYPTED_KEY_1
#              ,ENCRYPTED_KEY_2
#              ,NDC                                                                                 AS DRUG_CODE
#              ,COALESCE(STATEMENT_FROM,STATEMENT_TO,RECEIVED_DATE)                                 AS SERVICE_DATE
#              ,'0.0'                                                                               AS DAYS_SUPPLY
#
#        FROM  RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_PROCEDURE
#        WHERE NDC IN {ndc_codes}
# ;
# Out:
# Query started at 08:57:06 PM India Standard Time
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py", line 703, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py", line 873, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 457, in do_rollback
#     dbapi_connection.rollback()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py", line 384, in rollback
#     self.cursor().execute("ROLLBACK")
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py", line 479, in execute
#     _is_put_get=_is_put_get)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py", line 368, in _execute_helper
#     _no_results=_no_results)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py", line 638, in cmd_query
#     data, client=client, _no_results=_no_results)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\network.py", line 248, in request
#     timeout=self._connection.network_timeout)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\network.py", line 393, in _post_request
#     ret = self._renew_session()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\network.py", line 308, in _renew_session
#     u'sqlstate': SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 100, in errorhandler_wrapper
#     connection.errorhandler(connection, cursor, errorclass, errorvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 73, in default_errorhandler
#     done_format_msg=errorvalue.get(u'done_format_msg'))
# snowflake.connector.errors.ProgrammingError: 252007 (08001): Authentication token has expired.  The user must authenticate again.
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1193, in _execute_context
#     context)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 507, in do_execute
#     cursor.execute(statement, parameters)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py", line 542, in execute
#     errvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 97, in errorhandler_wrapper
#     cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 73, in default_errorhandler
#     done_format_msg=errorvalue.get(u'done_format_msg'))
# snowflake.connector.errors.ProgrammingError: 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 704, in _rollback_impl
#     self.engine.dialect.do_rollback(self.connection)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 457, in do_rollback
#     dbapi_connection.rollback()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py", line 384, in rollback
#     self.cursor().execute("ROLLBACK")
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py", line 542, in execute
#     errvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 97, in errorhandler_wrapper
#     cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 73, in default_errorhandler
#     done_format_msg=errorvalue.get(u'done_format_msg'))
# snowflake.connector.errors.ProgrammingError: 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1406, in _handle_dbapi_exception
#     self._autorollback()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 76, in __exit__
#     compat.reraise(type_, value, traceback)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 187, in reraise
#     raise value
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1406, in _handle_dbapi_exception
#     self._autorollback()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 827, in _autorollback
#     self._root._rollback_impl()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 706, in _rollback_impl
#     self._handle_dbapi_exception(e, None, None, None, None)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 1334, in _handle_dbapi_exception
#     exc_info
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 203, in raise_from_cause
#     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 186, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 704, in _rollback_impl
#     self.engine.dialect.do_rollback(self.connection)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 457, in do_rollback
#     dbapi_connection.rollback()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py", line 384, in rollback
#     self.cursor().execute("ROLLBACK")
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py", line 542, in execute
#     errvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 97, in errorhandler_wrapper
#     cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 73, in default_errorhandler
#     done_format_msg=errorvalue.get(u'done_format_msg'))
# sqlalchemy.exc.ProgrammingError: (snowflake.connector.errors.ProgrammingError) 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator. (Background on this error at: http://sqlalche.me/e/f405)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py", line 703, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py", line 873, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 457, in do_rollback
#     dbapi_connection.rollback()
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py", line 384, in rollback
#     self.cursor().execute("ROLLBACK")
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py", line 542, in execute
#     errvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 97, in errorhandler_wrapper
#     cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#   File "C:\Users\akmishra\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py", line 73, in default_errorhandler
#     done_format_msg=errorvalue.get(u'done_format_msg'))
# snowflake.connector.errors.ProgrammingError: 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator.
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py in execute(self, command, params, timeout, _do_reset, _put_callback, _put_callback_output_stream, _get_callback, _get_callback_output_stream, _statement_params, _is_internal, _no_results, _use_ijson, _is_put_get)
#     541                                        ProgrammingError,
# --> 542                                        errvalue)
#     543         return self
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py in errorhandler_wrapper(connection, cursor, errorclass, errorvalue)
#      96             cursor.messages.append((errorclass, errorvalue))
# ---> 97             cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#      98             return
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py in default_errorhandler(connection, cursor, errorclass, errorvalue)
#      72             sfqid=errorvalue.get(u'sfqid'),
# ---> 73             done_format_msg=errorvalue.get(u'done_format_msg'))
#      74
#
# ProgrammingError: 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator.
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _rollback_impl(self)
#     703             try:
# --> 704                 self.engine.dialect.do_rollback(self.connection)
#     705             except BaseException as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_rollback(self, dbapi_connection)
#     456     def do_rollback(self, dbapi_connection):
# --> 457         dbapi_connection.rollback()
#     458
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py in rollback(self)
#     383         """
# --> 384         self.cursor().execute("ROLLBACK")
#     385
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py in execute(self, command, params, timeout, _do_reset, _put_callback, _put_callback_output_stream, _get_callback, _get_callback_output_stream, _statement_params, _is_internal, _no_results, _use_ijson, _is_put_get)
#     541                                        ProgrammingError,
# --> 542                                        errvalue)
#     543         return self
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py in errorhandler_wrapper(connection, cursor, errorclass, errorvalue)
#      96             cursor.messages.append((errorclass, errorvalue))
# ---> 97             cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#      98             return
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py in default_errorhandler(connection, cursor, errorclass, errorvalue)
#      72             sfqid=errorvalue.get(u'sfqid'),
# ---> 73             done_format_msg=errorvalue.get(u'done_format_msg'))
#      74
#
# ProgrammingError: 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator.
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-83-8a92abca2104> in <module>()
# ----> 1 get_ipython().run_cell_magic('read_sql', '', "--Pulling all the patients taking techfidera drugs from RAVEN table.\nCREATE TABLE {db}.{schema}.{char_tbl}_MEDICAL_V1 AS\n      SELECT 'Medical'                                                                            AS SOURCE\n             ,CLAIM_NUMBER\n             ,ENCRYPTED_KEY_1\n             ,ENCRYPTED_KEY_2\n             ,NDC                                                                                 AS DRUG_CODE\n             ,COALESCE(STATEMENT_FROM,STATEMENT_TO,RECEIVED_DATE)                                 AS SERVICE_DATE\n             ,'0.0'                                                                               AS DAYS_SUPPLY\n\n       FROM  RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_PROCEDURE\n       WHERE NDC                            IN {ndc_codes}\n;")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-126> in read_sql(self, line, cell, local_ns)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sql_magic\sql_magic.py in read_sql(self, line, cell, local_ns)
#     147             t.start()
#     148         else:
# --> 149             result = self.conn.execute_sqls(statements, options)
#     150             if options['display']:
#     151                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sql_magic\connection.py in execute_sqls(self, sqls, options)
#     144         r = None
#     145         for i, s in enumerate(sqls, start=1):
# --> 146             r = self._read_sql_engine(s, options)
#     147         return r  # return last result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sql_magic\connection.py in _read_sql_engine(self, sql, options)
#     116         if caller is None:
#     117             raise ConnectionNotConfigured("A connection object must be configured using %config SQL.conn_name")
# --> 118         result, del_time, time_output = self._time_and_run_query(caller, sql)
#     119
#     120         if table_name:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sql_magic\connection.py in _time_and_run_query(self, caller, sql)
#     132         sys.stdout.write(time_output)
#     133         start_time = time.time()
# --> 134         result = caller(sql)
#     135         end_time = time.time()
#     136         del_time = (end_time - start_time) / 60.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sql_magic\connection.py in _run_db_sql(sql_code)
#      62         def _run_db_sql(sql_code):
#      63             try:
# ---> 64                 return psql.read_sql(sql_code, conn_object)
#      65             except(tuple(self.no_return_result_exceptions)):
#      66                 return EmptyResult()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     414             sql, index_col=index_col, params=params,
#     415             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 416             chunksize=chunksize)
#     417
#     418
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1090         args = _convert_params(sql, params)
#    1091
# -> 1092         result = self.execute(*args)
#    1093         columns = result.keys()
#    1094
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#     981     def execute(self, *args, **kwargs):
#     982         """Simple passthrough to SQLAlchemy connectable"""
# --> 983         return self.connectable.execute(*args, **kwargs)
#     984
#     985     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2073
#    2074         connection = self.contextual_connect(close_with_result=True)
# -> 2075         return connection.execute(statement, *multiparams, **params)
#    2076
#    2077     def scalar(self, statement, *multiparams, **params):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1404                     self._safe_close_cursor(cursor)
#    1405                 with util.safe_reraise(warn_only=True):
# -> 1406                     self._autorollback()
#    1407
#    1408             if newraise:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      74                     "is:\n %s %s\n" % (self._exc_info[0], self._exc_info[1]))
#      75             self._exc_info = None   # remove potential circular references
# ---> 76             compat.reraise(type_, value, traceback)
#      77
#      78
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1404                     self._safe_close_cursor(cursor)
#    1405                 with util.safe_reraise(warn_only=True):
# -> 1406                     self._autorollback()
#    1407
#    1408             if newraise:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _autorollback(self)
#     825     def _autorollback(self):
#     826         if not self._root.in_transaction():
# --> 827             self._root._rollback_impl()
#     828
#     829     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _rollback_impl(self)
#     704                 self.engine.dialect.do_rollback(self.connection)
#     705             except BaseException as e:
# --> 706                 self._handle_dbapi_exception(e, None, None, None, None)
#     707             finally:
#     708                 if not self.__invalid and \
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1332                                         self.dialect.dbapi.Error,
#    1333                                         dialect=self.dialect),
# -> 1334                 exc_info
#    1335             )
#    1336         self._reentrant_error = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _rollback_impl(self)
#     702                 self.engine.logger.info("ROLLBACK")
#     703             try:
# --> 704                 self.engine.dialect.do_rollback(self.connection)
#     705             except BaseException as e:
#     706                 self._handle_dbapi_exception(e, None, None, None, None)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_rollback(self, dbapi_connection)
#     455
#     456     def do_rollback(self, dbapi_connection):
# --> 457         dbapi_connection.rollback()
#     458
#     459     def do_commit(self, dbapi_connection):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\connection.py in rollback(self)
#     382         u"""Rollbacks the current transaction.
#     383         """
# --> 384         self.cursor().execute("ROLLBACK")
#     385
#     386     def cursor(self, cursor_class=SnowflakeCursor):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\cursor.py in execute(self, command, params, timeout, _do_reset, _put_callback, _put_callback_output_stream, _get_callback, _get_callback_output_stream, _statement_params, _is_internal, _no_results, _use_ijson, _is_put_get)
#     540             Error.errorhandler_wrapper(self.connection, self,
#     541                                        ProgrammingError,
# --> 542                                        errvalue)
#     543         return self
#     544
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py in errorhandler_wrapper(connection, cursor, errorclass, errorvalue)
#      95         if cursor is not None:
#      96             cursor.messages.append((errorclass, errorvalue))
# ---> 97             cursor.errorhandler(connection, cursor, errorclass, errorvalue)
#      98             return
#      99         elif connection is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\snowflake\connector\errors.py in default_errorhandler(connection, cursor, errorclass, errorvalue)
#      71             sqlstate=errorvalue.get(u'sqlstate'),
#      72             sfqid=errorvalue.get(u'sfqid'),
# ---> 73             done_format_msg=errorvalue.get(u'done_format_msg'))
#      74
#      75     @staticmethod
#
# ProgrammingError: (snowflake.connector.errors.ProgrammingError) 390420: IP 103.248.174.119 is not allowed to access Snowflake.  Contact your local security administrator. (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# This is such a small number that it is not worth brining in. Tecfidera is a drug that is typicallly ordered from the pharmacy and it would rarely show up in the procedures table. We'll keep it but it likley wasn't necessary to bring in

# %%
# %%read_sql
# --count of distinct patients and distinct claims from MEDICAL data
#     SELECT COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_MEDICAL_V1
#      WHERE ENCRYPTED_KEY_1 <> ' '
#            AND ENCRYPTED_KEY_1 IS NOT NULL
#            AND ENCRYPTED_KEY_1 <> 'NULL'
# Out:
# Query started at 11:53:39 PM India Standard Time; Query executed in 0.17 m
#    patient_count  claim_count
# 0            119         1453

# %% [markdown]
# These are extremely small counts and next time we will skip brining it in.

# %%
# %%read_sql
# --count of distinct patients and distinct claims for each ndc from MEDICAL data
#     SELECT DRUG_CODE ,
#            COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM PROJECT_ANALYTICS.Biogen.AKMISHRA_MEDICAL_TECHFIDERA_V1
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
#     GROUP BY DRUG_CODE
# ;
# Out:
# Query started at 11:53:53 PM India Standard Time; Query executed in 0.16 m
#      drug_code  patient_count  claim_count
# 0  64406000602            111         1395
# 1  64406000501              4            6
# 2  64406000703             34           51

# %% [markdown]
# ### Pelican EHR Data Pull
# All tecfidera records will be pulled from the EHR data.

# %%
# %%read_sql
# --Pulling all the patients taking techfidera drugs from Pelican table.
# CREATE Or Replace TABLE {db}.{schema}.{char_tbl}_PELICAN_V1 AS
#       SELECT 'Pelican_EHR'       AS SOURCE
#              ,B.PATIENT_ID
#              ,A.MEDICATION_ID    AS DRUG_CODE
#              ,B.START_DATE       AS SERVICE_DATE
#              ,'0.0'              AS DAYS_SUPPLY
#              ,PRESCRIPTION_ID
#
#        FROM  rwd_db.rwd.PELICAN_MEDICATION A
#              LEFT JOIN rwd_db.rwd.PELICAN_PRESCRIPTION B
#                     ON A.MEDICATION_ID   = B.MEDICATION_ID
#        WHERE A.MEDICATION_ID IN {ndc_codes}
# ;
# Out:
# Query started at 05:30:49 PM India Standard Time; Query executed in 0.36 m
#                                               status
# 0  Table AKMISHRA_PELICAN_TECHFIDERA_V1 successfu...

# %% [markdown]
# There are only 11,000 rows which is kind of small but we'll bring it in.

# %%
# %%read_sql
#
# --Pulling Patient_ID(ENCRYPTED_KEY_1,ENCRYPTED_KEY_2) for each Patient_ID
#
#     ALTER TABLE {db}.{schema}.{char_tbl}_PELICAN_V1
#       ADD (ENCRYPTED_KEY_1 VARCHAR(),
#            ENCRYPTED_KEY_2 VARCHAR()
#           );
#
#      UPDATE {db}.{schema}.{char_tbl}_PELICAN_V1                     A
#         SET A.ENCRYPTED_KEY_1 = B.ENCRYPTED_KEY_1,
#             A.ENCRYPTED_KEY_2 = B.ENCRYPTED_KEY_2
#        FROM rwd_db.rwd.PELICAN_DEID                                  B
#       WHERE A.PATIENT_ID = B.PATIENT_ID
#       ;
# Out:
# Query started at 05:31:25 PM India Standard Time; Query executed in 0.04 mQuery started at 05:31:27 PM India Standard Time; Query executed in 0.98 m
#    number of rows updated  number of multi-joined rows updated
# 0                   11168                                    0

# %% [markdown]
# It appears that some of the pelican tecfidera orders/scripts have a claim number.  I'm not sure what that means.

# %%
# %%read_sql
#
# --Pulling Claim_Number(TRANSCRIPT_ID) for each Prescription
#
#     ALTER TABLE {db}.{schema}.{char_tbl}_PELICAN_V1
#       ADD (CLAIM_NUMBER VARCHAR()
#           );
#
#      UPDATE {db}.{schema}.{char_tbl}_PELICAN_V1                             A
#         SET A.CLAIM_NUMBER = B.TRANSCRIPT_ID
#        FROM rwd_db.rwd.PELICAN_TRANSCRIPT_PRESCRIPTION                       B
#       WHERE A.PRESCRIPTION_ID = B.PRESCRIPTION_ID
#       ;
# Out:
# Query started at 05:51:27 PM India Standard Time; Query executed in 0.04 mQuery started at 05:51:29 PM India Standard Time; Query executed in 0.38 m
#    number of rows updated  number of multi-joined rows updated
# 0                    3190                                 1406

# %% [markdown]
# I'm not sure why there are fewer claims than patients.  I'm assuming that most of the Tecfidera didn't match to a claim.
# Per Akansha Pelican tends to be a bit smaller

# %%
# %%read_sql
# --count of distinct patients and distinct claims from PELICAN data
#     SELECT COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_PELICAN_V1
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
# Out:
# Query started at 12:20:46 AM India Standard Time; Query executed in 0.12 m
#    patient_count  claim_count
# 0           7356         3116

# %%
# %%read_sql
# --count of distinct patients and distinct claims for each ndc from PELICAN data
#     SELECT DRUG_CODE ,
#            COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_PELICAN_V1
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
#     GROUP BY DRUG_CODE
# ;
# Out:
# Query started at 12:20:58 AM India Standard Time; Query executed in 0.10 m
#      drug_code  patient_count  claim_count
# 0  64406000703            556          228
# 1  64406000501           1216          416
# 2  64406000602           6101         2518

# %% [markdown]
# ### Albatross EHR Data Pull
# The tecfidera orders from the EHR were extracted.  It appears we're pulling too many statuses per what Cindi Gettman recommended; however, our logic later to determine continuous enrollment actually may make this not a big deal. This may need to be revisited but for now it can remain.

# %%
# %%read_sql
# --Pulling all the patients taking techfidera drugs from Albatross table.
# CREATE TABLE {db}.{schema}.{char_tbl}_ALBATROSS_V2 AS
#       SELECT 'Albatross_EHR'                                                                      AS SOURCE
#              ,CAST(ENCOUNTERID AS STRING)                                                         AS CLAIM_NUMBER
#              ,ENCRYPTED_KEY_1
#              ,ENCRYPTED_KEY_2
#              ,NDC                                                                                 AS DRUG_CODE
#              ,TO_DATE(RECORDEDDTTM)                                                               AS SERVICE_DATE
#              ,daysupply                                                                           AS DAYS_SUPPLY
#              ,refills                                                                             AS REFILLS
#              ,quantitytodispense                                                                  AS QUANTITY_DISPENSED
#
#        FROM  RWD_DB.RWD.ALBATROSS_EHR_MEDICATIONS                                                 A
#
#        WHERE A.NDC             IN {ndc_codes}
#          AND UPPER(STATUS)     IN ('','ACTIVE','ADMINISTERED','AUTO COMPLETE','COMPLETE','COMPLETED','CONTINUED',
#                                    'DISCONTINUED','COMPLETE','COMPLETED','CONTINUED','DISCONTINUED','FILLED RX',
#                                    'HOLD FOR','IN PROGRESS','NEED INFORMATION','ORDERED','OTHER','PENDING','RESULTED')
# ;
# Out:
# Query started at 03:12:36 PM India Standard TimeInitiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ; Query executed in 35.78 m
#                                               status
# 0  Table AKMISHRA_TECFIDERA_ALBATROSS_V2 successf...

# %% [markdown]
# Not surpirsing we have 16k patients and 60k claims.  This is a high number and hopefully will overlap well with the lymphocyte tests.

# %%
# %%read_sql
# --count of distinct patients and distinct claims from MEDICAL data
#     SELECT COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_ALBATROSS_V2
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
# Out:
# Query started at 04:11:04 PM India Standard Time; Query executed in 0.23 m
#    patient_count  claim_count
# 0          16495        61341

# %% [markdown]
# The split between the drug codes is good.  We need to figure out which one is the starter pack.

# %%
# %%read_sql
# --count of distinct patients and distinct claims for each ndc from MEDICAL data
#     SELECT DRUG_CODE ,
#            COUNT(DISTINCT ENCRYPTED_KEY_1) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_ALBATROSS_V2
#      WHERE ENCRYPTED_KEY_1 <> ' '
#        AND ENCRYPTED_KEY_1 IS NOT NULL
#        AND ENCRYPTED_KEY_1 <> 'NULL'
#     GROUP BY DRUG_CODE
# ;
# Out:
# Query started at 04:11:43 PM India Standard Time; Query executed in 0.16 m
#      drug_code  patient_count  claim_count
# 0  64406000602          13822        48480
# 1  64406000501           2417         5839
# 2  64406000703           4980        11487

# %% [markdown]
# ## Create final raw data

# %% [markdown]
# ### Union raw Tecfidera Data
# Combining tables from all the datasources into one master tables
# * PRC - I never like performing massive unions of multiple data sources, and prefer using insert statements especially when data is large. However, for this size data it's an appropriate method.

# %%
# %%read_sql
#
# Create table {db}.{schema}.{char_tbl}_All_V2 as
#     Select Source,
#            CLAIM_NUMBER,
#            ENCRYPTED_KEY_1,
#            CASE WHEN ENCRYPTED_KEY_2 IS NULL THEN ENCRYPTED_KEY_1
#                 ELSE CONCAT(ENCRYPTED_KEY_1,ENCRYPTED_KEY_2) END                        AS  PATIENT_SUFFIX,
#             DRUG_CODE,
#             SERVICE_DATE,
#             Days_Supply,
#             0       AS REFILLS,
#             0       AS QUANTITY_DISPENSED
#
#        FROM {db}.{schema}.{char_tbl}_Pharmacy_V1
#       WHERE PATIENT_SUFFIX <> ' '
#         AND PATIENT_SUFFIX IS NOT NULL
#         AND PATIENT_SUFFIX <> 'NULL'
# UNION ALL
#     Select Source,
#            CLAIM_NUMBER,
#            ENCRYPTED_KEY_1,
#            CASE WHEN ENCRYPTED_KEY_2 IS NULL THEN ENCRYPTED_KEY_1
#                 ELSE CONCAT(ENCRYPTED_KEY_1,ENCRYPTED_KEY_2) END                        AS PATIENT_SUFFIX,
#
#             DRUG_CODE,
#             SERVICE_DATE,
#             Days_Supply,
#             0       AS REFILLS,
#             0       AS QUANTITY_DISPENSED
#
#        FROM {db}.{schema}.{char_tbl}_Medical_V1
#       WHERE PATIENT_SUFFIX <> ' '
#         AND PATIENT_SUFFIX IS NOT NULL
#         AND PATIENT_SUFFIX <> 'NULL'
#
# UNION ALL
#     Select Source,
#            CLAIM_NUMBER,
#            ENCRYPTED_KEY_1,
#            CASE WHEN ENCRYPTED_KEY_2 IS NULL THEN ENCRYPTED_KEY_1
#                 ELSE CONCAT(ENCRYPTED_KEY_1,ENCRYPTED_KEY_2) END                        AS PATIENT_SUFFIX,
#
#             DRUG_CODE,
#             SERVICE_DATE,
#             Days_Supply,
#             0       AS REFILLS,
#             0       AS QUANTITY_DISPENSED
#
#        FROM {db}.{schema}.{char_tbl}_Pelican_V1
#       WHERE PATIENT_SUFFIX <> ' '
#         AND PATIENT_SUFFIX IS NOT NULL
#         AND PATIENT_SUFFIX <> 'NULL'
#
# UNION ALL
#     Select Source,
#            CLAIM_NUMBER,
#            ENCRYPTED_KEY_1,
#            CASE WHEN ENCRYPTED_KEY_2 IS NULL THEN ENCRYPTED_KEY_1
#                 ELSE CONCAT(ENCRYPTED_KEY_1,ENCRYPTED_KEY_2) END                        AS PATIENT_SUFFIX,
#
#             DRUG_CODE,
#             SERVICE_DATE,
#             Days_Supply,
#             REFILLS,
#             QUANTITY_DISPENSED
#
#        FROM {db}.{schema}.{char_tbl}_ALBATROSS_V2
#       WHERE PATIENT_SUFFIX <> ' '
#         AND PATIENT_SUFFIX IS NOT NULL
#         AND PATIENT_SUFFIX <> 'NULL'
# Out:
# Query started at 04:16:05 PM India Standard Time; Query executed in 0.64 m
#                                               status
# 0  Table AKMISHRA_TECFIDERA_ALL_V2 successfully c...

# %% [markdown]
# 64k patients and 1.1 million claims is quite large. I'm not sure how this compares to our previous pull but for the most part it looks good

# %%
# %%read_sql
# --count of distinct patients and distinct claims from MEDICAL data
#     SELECT COUNT(DISTINCT PATIENT_SUFFIX) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_All_V2
# Out:
# Query started at 04:18:06 PM India Standard Time; Query executed in 0.08 m
#    patient_count  claim_count
# 0          64221      1100664

# %% [markdown]
# The divide between the drug codes is useful information, and we may capitlize on it later.

# %%
# %%read_sql
# --count of distinct patients and distinct claims from All data
#     SELECT Drug_Code,
#            COUNT(DISTINCT PATIENT_SUFFIX) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_All_V2
#       Group By 1
#       ;
# Out:
# Query started at 04:18:37 PM India Standard Time; Query executed in 0.05 m
#      drug_code  patient_count  claim_count
# 0  64406000602          57709      1004642
# 1  64406000501           6946        23008
# 2  64406000703          30678        77525

# %% [markdown]
# ### Limit Data to ALC Patients
# Reduce the Tecfidera population to only those patients who have at least 1 ALC test in the EHR.  Patients without any ALC tests would be excluded anyway and we want to eliminate patients to save computational time.

# %%
# %%read_sql
#
# DROP TABLE IF EXISTS {db}.{schema}.{char_tbl}_AlC_Final2;
#
# CREATE TABLE {db}.{schema}.{char_tbl}_AlC_Final2 As
#     SELECT A.*
#       FROM {db}.{schema}.{char_tbl}_ALL_V2      A
#            INNER JOIN PROJECT_ANALYTICS.Biogen.cbg_ALC_Combined     B
#                    ON A.PATIENT_SUFFIX  =  B.Patient_ID
# Out:
# Query started at 10:47:52 AM Eastern Daylight Time; Query executed in 0.05 mQuery started at 10:47:55 AM Eastern Daylight Time; Query executed in 0.20 m
#                                               status
# 0  Table AKMISHRA_TECFIDERA_ALC_FINAL2 successful...

# %% [markdown]
# Reducing to 2700 patients with around 60k tecfidera orders is in line with what was done previously. This patient count is expected to drop further once we reduce to those that were on it continuously for 90 days and had a baseline ALC.  We may have a much smaller cohort than what we had previously.

# %%
# %%read_sql
# --count of distinct patients and distinct claims from Tec + ALC data
#     SELECT COUNT(DISTINCT PATIENT_SUFFIX) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_AlC_Final2
# Out:
# Query started at 10:48:11 AM Eastern Daylight Time; Query executed in 0.19 m
#    patient_count  claim_count
# 0           5318        68080

# %% [markdown]
# Counts of the drug codes are in line with what was done previously.

# %%
# %%read_sql
# --count of distinct patients and distinct claims from Tec + ALC  data
#     SELECT Drug_code,
#            COUNT(DISTINCT PATIENT_SUFFIX) AS PATIENT_COUNT,
#            COUNT(DISTINCT CLAIM_NUMBER)    AS CLAIM_COUNT
#       FROM {db}.{schema}.{char_tbl}_AlC_Final2
#      group by 1
# Out:
# Query started at 10:48:28 AM Eastern Daylight Time; Query executed in 0.15 m
#      drug_code  patient_count  claim_count
# 0  64406000602           4679        59096
# 1  64406000501            942         2948
# 2  64406000703           2721         8016

# %% [markdown]
# ## Continuous RX Analysis
# Determine which med orders are continuous in this population

# %%
# %%read_sql -d Akmishra_TECFIDERA
#
#     SELECT Distinct SOURCE
#           ,CLAIM_NUMBER
#           ,PATIENT_SUFFIX
#           ,SERVICE_DATE
#           ,DRUG_CODE
#           ,DAYS_SUPPLY
#           ,REFILLS
#           ,QUANTITY_DISPENSED
#     FROM  {db}.{schema}.{char_tbl}_AlC_Final2
#     WHERE PATIENT_SUFFIX IS NOT NULL
#           AND SOURCE <> 'Pelican_EHR'
#           AND source <> 'Medical'
#           AND PATIENT_SUFFIX <> ''
#           AND PATIENT_SUFFIX <> 'NULL'
#           AND service_date > '3/1/2013'
#           AND service_date is not null
#     ORDER BY PATIENT_SUFFIX,SERVICE_DATE
# ;
# Out:
# Query started at 10:48:43 AM Eastern Daylight Time; Query executed in 0.45 m

# %%
#Delete where the service date is null
Akmishra_TECFIDERA = Akmishra_TECFIDERA.dropna(subset=['service_date'])

# %% [markdown]
# Set null days_supply and refills to 0 if the data is null

# %%
#Set the service_date to a date insetad of an object
Akmishra_TECFIDERA.service_date = pd.to_datetime(Akmishra_TECFIDERA.service_date)

# %%
#Set nulls to zero and then turn into numerics
Akmishra_TECFIDERA.loc[pd.isnull(Akmishra_TECFIDERA.days_supply),'days_supply'] = 0
Akmishra_TECFIDERA.loc[pd.isnull(Akmishra_TECFIDERA.refills),'refills'] = 0
Akmishra_TECFIDERA.loc[pd.isnull(Akmishra_TECFIDERA.quantity_dispensed),'quantity_dispensed'] = 0

Akmishra_TECFIDERA['days_supply'] = pd.to_numeric(Akmishra_TECFIDERA['days_supply'])
Akmishra_TECFIDERA['refills'] = pd.to_numeric(Akmishra_TECFIDERA['refills'])
Akmishra_TECFIDERA['quantity_dispensed'] = pd.to_numeric(Akmishra_TECFIDERA['quantity_dispensed'])

# %%
#Set days_supply_final to the max of the following
Akmishra_TECFIDERA['days_supply_final'] = (
    Akmishra_TECFIDERA.apply(lambda row: max(row.days_supply,
                                             row.quantity_dispensed / 2,
                                             row.refills * 30),
                             axis=1))

# %%
#Drop the records where the days_supply_final is zero.  These are likely bad records
Akmishra_TECFIDERA = Akmishra_TECFIDERA[Akmishra_TECFIDERA.days_supply_final > 0]

# %%
#Set end date (this was in a loop previously and is unnecesary)
Akmishra_TECFIDERA['end_date'] =  (
    Akmishra_TECFIDERA.apply(
        lambda row: row.service_date + timedelta(days=row.days_supply_final),
        axis=1))

# %%
# %%read_sql
# Drop table {db}.{schema}.Akmishra_TECFIDERA_Enddate
# Out:
# Query started at 10:50:15 AM Eastern Daylight Time; Query executed in 0.11 m
#                                              status
# 0  AKMISHRA_TECFIDERA_ENDDATE successfully dropped.

# %%
snow.upload_dataframe(Akmishra_TECFIDERA, 'Akmishra_TECFIDERA_Enddate', schema = 'BIOGEN')
# Out:
# Upload Successful!

# %%
# %%read_sql Akmishra_TECFIDERA_updated
#     SELECT Distinct A.* ,
#            max(B.end_date) over (partition by A.patient_suffix,A.service_date order by A.service_date) as Final_end_date
#       FROM {db}.{schema}.Akmishra_TECFIDERA_Enddate    A
#            inner join {db}.{schema}.Akmishra_TECFIDERA_Enddate    B
#                    on A.PATIENT_SUFFIX = B.PATIENT_SUFFIX
#                   and B.Service_date  <= A.service_date
#      order by patient_suffix, service_date
# Out:
# Query started at 10:52:14 AM Eastern Daylight Time; Query executed in 0.25 m
#               source        claim_number  \
# 0           PHARMACY  120885000000732130
# 1           PHARMACY  118797000005181837
# 2           PHARMACY  119712000003522834
# 3           PHARMACY  120514000001906631
# 4           PHARMACY  121390000007842534
# 5           PHARMACY  122372000002401835
# 6           PHARMACY  123206000002836340
# 7           PHARMACY  124349000001780604
# 8           PHARMACY  125174000004389536
# 9      Albatross_EHR            17231300
# 10     Albatross_EHR            19033345
# 11     Albatross_EHR            19543716
# 12     Albatross_EHR            21840529
# 13     Albatross_EHR            22161109
# 14     Albatross_EHR            23148648
# 15     Albatross_EHR            23581674
# 16          PHARMACY  100631000004468462
# 17          PHARMACY  100631000003506317
# 18          PHARMACY  100631000003556884
# 19          PHARMACY  100769000002393064
# 20          PHARMACY  100769000000156967
# 21          PHARMACY  103040000002113834
# 22          PHARMACY  103040000001008049
# 23          PHARMACY  103981000000597403
# 24          PHARMACY  103981000004151500
# 25          PHARMACY          3433893198
# 26          PHARMACY          3501981589
# 27          PHARMACY          3579404569
# 28          PHARMACY          3653608704
# 29          PHARMACY          3734940861
# ...              ...                 ...
# 66532       PHARMACY  206481000000319694
# 66533       PHARMACY  206481000000644944
# 66534       PHARMACY  206481000000323231
# 66535       PHARMACY  206532000003360351
# 66534               90.0 2016-11-20     2016-11-20
# 66535               30.0 2016-09-22     2016-11-20
# 66536               30.0 2016-11-06     2017-01-05
# 66537               90.0 2017-01-05     2017-01-05
# 66538               30.0 2016-11-06     2017-01-05
# 66539                1.0 2017-08-02     2017-08-02
# 66540               90.0 2013-09-17     2013-09-17
# 66541               30.0 2013-09-05     2013-09-17
# 66542               30.0 2013-09-06     2013-09-17
# 66543               30.0 2013-09-11     2013-09-17
# 66544               30.0 2013-12-13     2013-12-13
# 66545               30.0 2013-08-28     2013-08-28
# 66546               30.0 2013-08-28     2013-08-28
# 66547               30.0 2013-08-29     2013-08-29
# 66548               30.0 2013-10-19     2013-10-19
# 66549               30.0 2013-11-22     2013-11-22
# 66550               30.0 2013-12-20     2013-12-20
# 66551               30.0 2015-11-07     2015-11-07
# 66552               30.0 2016-06-18     2016-06-18
# 66553               90.0 2018-05-20     2018-05-20
# 66554               90.0 2018-05-21     2018-05-21
# 66555              150.0 2016-03-19     2016-03-19
# 66556               30.0 2016-12-11     2016-12-11
# 66557               90.0 2017-02-13     2017-02-13
# 66558               90.0 2013-09-02     2013-09-02
# 66559               90.0 2013-09-10     2013-09-10
# 66560               90.0 2013-09-11     2013-09-11
# 66561               90.0 2013-12-09     2013-12-09
#
# [66562 rows x 11 columns]

# %%
#Run the shift.  
Akmishra_TECFIDERA_updated['lag_end_date'] = Akmishra_TECFIDERA_updated.groupby(['patient_suffix'])['final_end_date'].shift(1)
Akmishra_TECFIDERA_updated['lag_end_date'] = pd.to_datetime(Akmishra_TECFIDERA_updated['lag_end_date'])

# %%
Akmishra_TECFIDERA_updated = Akmishra_TECFIDERA_updated.reset_index(drop=True)

# %%
#Review top few rows to ensure calculation is right
Akmishra_TECFIDERA_updated.head(100)
# Out:
#            source        claim_number  \
# 0        PHARMACY  120885000000732130
# 1        PHARMACY  118797000005181837
# 2        PHARMACY  119712000003522834
# 3        PHARMACY  120514000001906631
# 4        PHARMACY  121390000007842534
# 5        PHARMACY  122372000002401835
# 6        PHARMACY  123206000002836340
# 7        PHARMACY  124349000001780604
# 8        PHARMACY  125174000004389536
# 9   Albatross_EHR            17231300
# 10  Albatross_EHR            19033345
# 11  Albatross_EHR            19543716
# 12  Albatross_EHR            21840529
# 13  Albatross_EHR            22161109
# 14  Albatross_EHR            23148648
# 15  Albatross_EHR            23581674
# 16       PHARMACY  100631000004468462
# 17       PHARMACY  100631000003506317
# 18       PHARMACY  100631000003556884
# 19       PHARMACY  100769000002393064
# 20       PHARMACY  100769000000156967
# 21       PHARMACY  103040000002113834
# 22       PHARMACY  103040000001008049
# 23       PHARMACY  103981000000597403
# 24       PHARMACY  103981000004151500
# 25       PHARMACY          3433893198
# 26       PHARMACY          3501981589
# 27       PHARMACY          3579404569
# 28       PHARMACY          3653608704
# 29       PHARMACY          3734940861
# ..            ...                 ...
# 70       PHARMACY  109069000003683989
# 71       PHARMACY  109998000001889650
# 72       PHARMACY  110934000005855663
# 73       PHARMACY  112183000004327295
# 74       PHARMACY  113261000005416186
# 13 2016-10-16     2016-10-16   2016-08-29
# 14 2017-03-09     2017-03-09   2016-10-16
# 15 2017-05-09     2017-05-09   2017-03-09
# 16 2013-09-15     2013-09-15          NaT
# 17 2013-07-17     2013-09-15   2013-09-15
# 18 2013-07-17     2013-09-15   2013-09-15
# 19 2013-07-24     2013-09-15   2013-09-15
# 20 2013-07-24     2013-09-15   2013-09-15
# 21 2013-09-21     2013-09-21   2013-09-15
# 22 2013-09-21     2013-09-21   2013-09-21
# 23 2013-10-17     2013-10-17   2013-09-21
# 24 2013-10-17     2013-10-17   2013-10-17
# 25 2013-09-11     2013-09-11          NaT
# 26 2013-10-04     2013-10-04   2013-09-11
# 27 2013-10-31     2013-10-31   2013-10-04
# 28 2013-11-24     2013-11-24   2013-10-31
# 29 2013-12-22     2013-12-22   2013-11-24
# ..        ...            ...          ...
# 70 2014-03-14     2014-03-14   2014-03-14
# 71 2014-04-10     2014-04-10   2014-03-14
# 72 2014-05-07     2014-05-07   2014-04-10
# 73 2014-06-11     2014-06-11   2014-05-07
# 74 2014-07-11     2014-07-11   2014-06-11
# 75 2014-08-15     2014-08-15   2014-07-11
# 76 2014-10-02     2014-10-02   2014-08-15
# 77 2014-10-25     2014-10-25   2014-10-02
# 78 2014-12-07     2014-12-07   2014-10-25
# 79 2014-12-07     2014-12-07   2014-12-07
# 80 2015-01-08     2015-01-08   2014-12-07
# 81 2015-02-06     2015-02-06   2015-01-08
# 82 2015-03-14     2015-03-14   2015-02-06
# 83 2015-04-15     2015-04-15   2015-03-14
# 84 2015-04-15     2015-04-15   2015-04-15
# 85 2015-05-14     2015-05-14   2015-04-15
# 86 2015-06-17     2015-06-17   2015-05-14
# 87 2015-07-18     2015-07-18   2015-06-17
# 88 2015-08-21     2015-08-21   2015-07-18
# 89 2015-09-24     2015-09-24   2015-08-21
# 90 2015-10-22     2015-10-22   2015-09-24
# 91 2015-11-29     2015-11-29   2015-10-22
# 92 2015-11-29     2015-11-29   2015-11-29
# 93 2015-12-27     2015-12-27   2015-11-29
# 94 2016-02-05     2016-02-05   2015-12-27
# 95 2016-03-05     2016-03-05   2016-02-05
# 96 2016-05-06     2016-05-06   2016-03-05
# 97 2016-11-20     2016-11-20   2016-05-06
# 98 2016-09-23     2016-09-23          NaT
# 99 2016-09-23     2016-09-23   2016-09-23
#
# [100 rows x 12 columns]

# %% [markdown]
# ### Determine continuous records
# Checking if the patient is coming for next refill on or before the enddate of prior refill.

# %%
Akmishra_TECFIDERA_updated['delta'] = Akmishra_TECFIDERA_updated.apply(lambda row:(row.service_date - row.lag_end_date).days , axis = 1).fillna(0)  
Akmishra_TECFIDERA_updated['delta'] = pd.to_numeric(Akmishra_TECFIDERA_updated['delta'])

# %%
Akmishra_TECFIDERA_updated['is_outside_buffer_60'] = Akmishra_TECFIDERA_updated.groupby('patient_suffix')['delta'].apply(lambda x: x > buffer_60) 
Akmishra_TECFIDERA_updated['is_outside_buffer_90'] = Akmishra_TECFIDERA_updated.groupby('patient_suffix')['delta'].apply(lambda x: x > buffer_90) 
Akmishra_TECFIDERA_updated['is_outside_buffer_120'] = Akmishra_TECFIDERA_updated.groupby('patient_suffix')['delta'].apply(lambda x: x > buffer_120) 
Akmishra_TECFIDERA_updated['total_60'] = Akmishra_TECFIDERA_updated.groupby('patient_suffix')['is_outside_buffer_60'].cumsum().astype(int) 
Akmishra_TECFIDERA_updated['total_90'] = Akmishra_TECFIDERA_updated.groupby('patient_suffix')['is_outside_buffer_90'].cumsum().astype(int) 
Akmishra_TECFIDERA_updated['total_120'] = Akmishra_TECFIDERA_updated.groupby('patient_suffix')['is_outside_buffer_120'].cumsum().astype(int)

# %%
Akmishra_TECFIDERA_updated.head(100)
# Out:
#            source        claim_number  \
# 0        PHARMACY  120885000000732130
# 1        PHARMACY  118797000005181837
# 2        PHARMACY  119712000003522834
# 3        PHARMACY  120514000001906631
# 4        PHARMACY  121390000007842534
# 5        PHARMACY  122372000002401835
# 6        PHARMACY  123206000002836340
# 7        PHARMACY  124349000001780604
# 8        PHARMACY  125174000004389536
# 9   Albatross_EHR            17231300
# 10  Albatross_EHR            19033345
# 11  Albatross_EHR            19543716
# 12  Albatross_EHR            21840529
# 13  Albatross_EHR            22161109
# 14  Albatross_EHR            23148648
# 15  Albatross_EHR            23581674
# 16       PHARMACY  100631000004468462
# 17       PHARMACY  100631000003506317
# 18       PHARMACY  100631000003556884
# 19       PHARMACY  100769000002393064
# 20       PHARMACY  100769000000156967
# 21       PHARMACY  103040000002113834
# 22       PHARMACY  103040000001008049
# 23       PHARMACY  103981000000597403
# 24       PHARMACY  103981000004151500
# 25       PHARMACY          3433893198
# 26       PHARMACY          3501981589
# 27       PHARMACY          3579404569
# 28       PHARMACY          3653608704
# 29       PHARMACY          3734940861
# ..            ...                 ...
# 70       PHARMACY  109069000003683989
# 71       PHARMACY  109998000001889650
# 72       PHARMACY  110934000005855663
# 73       PHARMACY  112183000004327295
# 74       PHARMACY  113261000005416186
# 75       PHARMACY  114361000001504619
# 76       PHARMACY  115825000005972826
# 77       PHARMACY  116507000005141344
# 78       PHARMACY  117794000003238038
# 79       PHARMACY  117794000002646765
# 80       PHARMACY  118756000004125969
# 81       PHARMACY  119575000003666610
# 82       PHARMACY  120596000001364802
# 83       PHARMACY  121580000002164298
# 84       PHARMACY  121580000003179271
# 85       PHARMACY  122403000001867150
# 86       PHARMACY  123394000003186368
# 87       PHARMACY  124590000002075591
# 88       PHARMACY  125588000002349022
# 89       PHARMACY  126644000001792292
# 90       PHARMACY  127362000005991432
# 91       PHARMACY  128406000002406486
# 92       PHARMACY  128406000002407997
# 93       PHARMACY  129204000001780634
# 94       PHARMACY  140397000002030666
# 95       PHARMACY  146035000003239622
# 96       PHARMACY  154240000003282950
# 97  Albatross_EHR            40665193
# 98  Albatross_EHR            20534993
# 99  Albatross_EHR            20395182
#
#                                        patient_suffix service_date  \
# 0   ++VVDQWrctCOQnfuzfdAdfaxsZikGe2MFiaydTBA9Cs=lA...   2014-11-13
# 19                 False                  False         0         0          0
# 20                 False                  False         0         0          0
# 21                 False                  False         0         0          0
# 22                 False                  False         0         0          0
# 23                 False                  False         0         0          0
# 24                 False                  False         0         0          0
# 25                 False                  False         0         0          0
# 26                 False                  False         0         0          0
# 27                 False                  False         0         0          0
# 28                 False                  False         0         0          0
# 29                 False                  False         0         0          0
# ..                   ...                    ...       ...       ...        ...
# 70                 False                  False         0         0          0
# 71                 False                  False         0         0          0
# 72                 False                  False         0         0          0
# 73                 False                  False         0         0          0
# 74                 False                  False         0         0          0
# 75                 False                  False         0         0          0
# 76                 False                  False         0         0          0
# 77                 False                  False         0         0          0
# 78                 False                  False         0         0          0
# 79                 False                  False         0         0          0
# 80                 False                  False         0         0          0
# 81                 False                  False         0         0          0
# 82                 False                  False         0         0          0
# 83                 False                  False         0         0          0
# 84                 False                  False         0         0          0
# 85                 False                  False         0         0          0
# 86                 False                  False         0         0          0
# 87                 False                  False         0         0          0
# 88                 False                  False         0         0          0
# 89                 False                  False         0         0          0
# 90                 False                  False         0         0          0
# 91                 False                  False         0         0          0
# 92                 False                  False         0         0          0
# 93                 False                  False         0         0          0
# 94                 False                  False         0         0          0
# 95                 False                  False         0         0          0
# 96                 False                  False         0         0          0
# 97                  True                  False         1         1          0
# 98                 False                  False         0         0          0
# 99                 False                  False         0         0          0
#
# [100 rows x 19 columns]

# %%
Akmishra_TECFIDERA_updated['total_60']  =  Akmishra_TECFIDERA_updated['total_60'] + 1
Akmishra_TECFIDERA_updated['total_90']  =  Akmishra_TECFIDERA_updated['total_90'] + 1
Akmishra_TECFIDERA_updated['total_120'] =  Akmishra_TECFIDERA_updated['total_120'] + 1

# %%
Akmishra_TECFIDERA_updated.head(50)
# Out:
#            source        claim_number  \
# 0        PHARMACY  120885000000732130
# 1        PHARMACY  118797000005181837
# 2        PHARMACY  119712000003522834
# 3        PHARMACY  120514000001906631
# 4        PHARMACY  121390000007842534
# 5        PHARMACY  122372000002401835
# 6        PHARMACY  123206000002836340
# 7        PHARMACY  124349000001780604
# 8        PHARMACY  125174000004389536
# 9   Albatross_EHR            17231300
# 10  Albatross_EHR            19033345
# 11  Albatross_EHR            19543716
# 12  Albatross_EHR            21840529
# 13  Albatross_EHR            22161109
# 14  Albatross_EHR            23148648
# 15  Albatross_EHR            23581674
# 16       PHARMACY  100631000004468462
# 17       PHARMACY  100631000003506317
# 18       PHARMACY  100631000003556884
# 19       PHARMACY  100769000002393064
# 20       PHARMACY  100769000000156967
# 21       PHARMACY  103040000002113834
# 22       PHARMACY  103040000001008049
# 23       PHARMACY  103981000000597403
# 24       PHARMACY  103981000004151500
# 25       PHARMACY          3433893198
# 26       PHARMACY          3501981589
# 27       PHARMACY          3579404569
# 28       PHARMACY          3653608704
# 29       PHARMACY          3734940861
# 30       PHARMACY          3863684696
# 31       PHARMACY          3934494849
# 32       PHARMACY          4011490736
# 33       PHARMACY          4113637169
# 34       PHARMACY          4188885951
# 35       PHARMACY          4280297212
# 36       PHARMACY          4351173864
# 2                  False                  False         1         1          1
# 3                  False                  False         1         1          1
# 4                  False                  False         1         1          1
# 5                  False                  False         1         1          1
# 6                  False                  False         1         1          1
# 7                  False                  False         1         1          1
# 8                  False                  False         1         1          1
# 9                  False                  False         1         1          1
# 10                  True                   True         2         2          2
# 11                 False                  False         2         2          2
# 12                  True                   True         3         3          3
# 13                 False                  False         3         3          3
# 14                 False                  False         3         3          3
# 15                 False                  False         3         3          3
# 16                 False                  False         1         1          1
# 17                 False                  False         1         1          1
# 18                 False                  False         1         1          1
# 19                 False                  False         1         1          1
# 20                 False                  False         1         1          1
# 21                 False                  False         1         1          1
# 22                 False                  False         1         1          1
# 23                 False                  False         1         1          1
# 24                 False                  False         1         1          1
# 25                 False                  False         1         1          1
# 26                 False                  False         1         1          1
# 27                 False                  False         1         1          1
# 28                 False                  False         1         1          1
# 29                 False                  False         1         1          1
# 30                 False                  False         1         1          1
# 31                 False                  False         1         1          1
# 32                 False                  False         1         1          1
# 33                 False                  False         1         1          1
# 34                 False                  False         1         1          1
# 35                 False                  False         1         1          1
# 36                 False                  False         1         1          1
# 37                 False                  False         1         1          1
# 38                 False                  False         1         1          1
# 39                 False                  False         1         1          1
# 40                 False                  False         1         1          1
# 41                 False                  False         1         1          1
# 42                 False                  False         1         1          1
# 43                 False                  False         1         1          1
# 44                 False                  False         1         1          1
# 45                 False                  False         1         1          1
# 46                 False                  False         1         1          1
# 47                 False                  False         1         1          1
# 48                 False                  False         1         1          1
# 49                 False                  False         1         1          1

# %% [markdown]
# ### Uploading final table to snowflake

# %%
snow.upload_dataframe(Akmishra_TECFIDERA_updated, 'Akmishra_TECFIDERA_full_detail_final', schema = 'BIOGEN')
# Out:
# Table already exists. Dropping it.
# DROP TABLE IF EXISTS project_analytics.biogen.akmishra_tecfidera_full_detail_final;
# Table successfully dropped!
# Upload Successful!

# %% [markdown]
# ## Final data prep

# %%
# %%read_sql
# desc table Akmishra_TECFIDERA_full_detail_final;
# Out:
# Query started at 10:56:19 AM Eastern Daylight Time; Query executed in 0.07 m
#                      name               type    kind null? default  \
# 0                  SOURCE  VARCHAR(16777216)  COLUMN     Y    None
# 1            CLAIM_NUMBER  VARCHAR(16777216)  COLUMN     Y    None
# 2          PATIENT_SUFFIX  VARCHAR(16777216)  COLUMN     Y    None
# 3            SERVICE_DATE   TIMESTAMP_NTZ(9)  COLUMN     Y    None
# 4               DRUG_CODE  VARCHAR(16777216)  COLUMN     Y    None
# 5             DAYS_SUPPLY              FLOAT  COLUMN     Y    None
# 6                 REFILLS              FLOAT  COLUMN     Y    None
# 7      QUANTITY_DISPENSED              FLOAT  COLUMN     Y    None
# 8       DAYS_SUPPLY_FINAL              FLOAT  COLUMN     Y    None
# 9                END_DATE   TIMESTAMP_NTZ(9)  COLUMN     Y    None
# 10         FINAL_END_DATE   TIMESTAMP_NTZ(9)  COLUMN     Y    None
# 11           LAG_END_DATE   TIMESTAMP_NTZ(9)  COLUMN     Y    None
# 12                  DELTA              FLOAT  COLUMN     Y    None
# 13   IS_OUTSIDE_BUFFER_60            BOOLEAN  COLUMN     Y    None
# 14   IS_OUTSIDE_BUFFER_90            BOOLEAN  COLUMN     Y    None
# 15  IS_OUTSIDE_BUFFER_120            BOOLEAN  COLUMN     Y    None
# 16               TOTAL_60       NUMBER(38,0)  COLUMN     Y    None
# 17               TOTAL_90       NUMBER(38,0)  COLUMN     Y    None
# 18              TOTAL_120       NUMBER(38,0)  COLUMN     Y    None
#
#    primary key unique key check expression comment
# 0            N          N  None       None    None
# 1            N          N  None       None    None
# 2            N          N  None       None    None
# 3            N          N  None       None    None
# 4            N          N  None       None    None
# 5            N          N  None       None    None
# 6            N          N  None       None    None
# 7            N          N  None       None    None
# 8            N          N  None       None    None
# 9            N          N  None       None    None
# 10           N          N  None       None    None
# 11           N          N  None       None    None
# 12           N          N  None       None    None
# 13           N          N  None       None    None
# 14           N          N  None       None    None
# 15           N          N  None       None    None
# 16           N          N  None       None    None
# 17           N          N  None       None    None
# 18           N          N  None       None    None

# %% [markdown]
# Add starter pack flag so we can see if the continuous period the patient likley started Tecfidera

# %%
# %%read_sql
# ALTER TABLE Akmishra_TECFIDERA_full_detail_final
#         ADD starter_pack varchar(10)
# Out:
# Query started at 10:56:29 AM Eastern Daylight Time; Query executed in 0.07 m
#                              status
# 0  Statement executed successfully.

# %%
# %%read_sql
#
# UPDATE Akmishra_TECFIDERA_full_detail_final
#    SET starter_pack = 1
#  WHERE DRUG_CODE = '64406000501'
# Out:
# Query started at 10:56:33 AM Eastern Daylight Time; Query executed in 0.14 m
#    number of rows updated  number of multi-joined rows updated
# 0                    2518                                    0

# %% [markdown]
# ## Pulling all the required fields

# %%
# %%read_sql
#     select count(distinct patient_suffix) as pat_count
#           ,count(distinct claim_number)   as claim_count
#           ,sum(starter_pack)              as start_pack
#     from Akmishra_TECFIDERA_full_detail_final
# Out:
# Query started at 10:56:42 AM Eastern Daylight Time; Query executed in 0.14 m
#    pat_count  claim_count  start_pack
# 0       4429        63566      2518.0

# %%
snow.select('SELECT * FROM Akmishra_TECFIDERA_full_detail_final').to_excel("C:\GitHub\Lymphocyte\Tec_cont_raw_final.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-db43d2c1fc79> in <module>()
# ----> 1 snow.select('SELECT * FROM Akmishra_TECFIDERA_full_detail_final').to_excel("C:\GitHub\Lymphocyte\Tec_cont_raw_final.xlsx",index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1543         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1544                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1545                         engine=engine)
#    1546
#    1547     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     649                            freeze_panes=freeze_panes)
#     650         if need_save:
# --> 651             writer.save()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py in save(self)
#    1600         """
#    1601
# -> 1602         return self.book.close()
#    1603
#    1604     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     308         if not self.fileclosed:
#     309             self.fileclosed = 1
# --> 310             self._store_workbook()
#     311
#     312     def set_size(self, width, height):
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     622
#     623         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 624                             allowZip64=self.allow_zip64)
#     625
#     626         # Add XML sub-files to the Zip file with their Excel filename.
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\GitHub\\Lymphocyte\\Tec_cont_raw_final.xlsx'

# %%
# %%read_sql
#     Select Distinct Source,
#            patient_suffix,
#            min(service_date) over (partition by patient_suffix)         AS TEC_START_DATE,
#            max(enddate) over (partition by patient_suffix)              AS TEC_END_DATE,
#            DATEDIFF(day,(min(service_date) over (partition by patient_suffix)),(max(enddate) over (partition by patient_suffix)))   AS Medication_enrollment_period,
#            Count                                                        AS EPISODE,
#            min(service_date) over (partition by patient_suffix,count)   AS EPI_START_DATE,
#            max(service_date) over (partition by patient_suffix,count)   AS EPI_END_DATE,
#            DATEDIFF(day,(min(service_date) over (partition by patient_suffix,count)),(max(enddate) over (partition by patient_suffix,count))) as EPISODE_PERIOD
#       FROM Akmishra_TECFIDERA_full_detail_final

# %%
# !dir
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 32EB-0EFD
#
#  Directory of C:\GitHub\Biogen_lymphocyte
#
# 04/09/2018  11:30 AM    <DIR>          .
# 04/09/2018  11:30 AM    <DIR>          ..
# 12/15/2017  12:17 PM               139 .gitignore
# 04/03/2018  04:15 PM    <DIR>          .ipynb_checkpoints
# 04/05/2018  09:50 AM                 0 .Rhistory
# 12/21/2017  11:26 PM           269,813 01_Biogen Lab Mappings_Cindi.sql
# 04/09/2018  09:31 AM            13,194 02_Biogen Lymphocytes_Albatross_Cindi.sql
# 04/09/2018  11:01 AM            11,353 03_Biogen Lymphocytes Pelican_Cindi.sql
# 12/14/2017  04:51 PM            47,846 ALC_Cohort_SQL_code.SQL
# 11/22/2017  11:09 AM            65,566 Biogen_Lymphocyte_SQL_Code.sql
# 12/14/2017  04:51 PM            18,658 Continuous_Enrollment_Code.SQL
# 01/29/2018  12:13 PM    <DIR>          data
# 12/14/2017  04:51 PM            12,963 DMT_Cohort_SQL_code_v1.sql
# 04/03/2018  04:15 PM           373,971 example_data.csv
# 12/14/2017  04:51 PM             6,717 Multiple_Sclerosis_Cohort_SQL_code_v1.sql
# 04/04/2018  04:45 PM    <DIR>          out
# 11/29/2017  05:40 PM             1,438 Quick_Analysis_output.sql
# 12/14/2017  04:51 PM             1,420 README.md
# 03/22/2018  07:12 PM    <DIR>          ref
# 12/08/2017  04:09 PM               954 SFA.lnk
# 01/08/2018  05:40 PM            17,640 Spaghetti_Plot.do
# 01/12/2018  03:17 PM           776,426 Summary_Stats_01_R.html
# 04/06/2018  08:03 PM            27,556 Summary_Stats_01_R.Rmd
# 04/06/2018  08:03 PM            30,639 Summary_Stats_01_sql.sql
# 12/08/2017  05:03 PM             2,335 Tecfidera_ALC_Baseline_count.sql
# 12/14/2017  04:51 PM             7,524 Tecfidera_Cohort_SQL_code.sql
# 04/09/2018  10:59 AM           386,024 Tecfidera_Continuous_Enrollment.ipynb
# 04/09/2018  08:08 AM         5,664,477 Tec_cont_raw_final.xlsx
# 11/01/2017  03:11 PM                38 testtext.txt
# 03/22/2018  07:31 PM            10,066 Update_01_Create_Ref_table.ipynb
# 03/22/2018  07:43 PM             3,080 update_02_extract_Rx_claims.ipynb
#               25 File(s)      7,749,837 bytes
#                6 Dir(s)  17,669,451,776 bytes free
#  Volume in drive C has no label.
#  Volume Serial Number is 32EB-0EFD
#
#  Directory of C:\GitHub\Biogen_lymphocyte
#
# 04/09/2018  11:30 AM    <DIR>          .
# 04/09/2018  11:30 AM    <DIR>          ..
# 12/15/2017  12:17 PM               139 .gitignore
# 04/03/2018  04:15 PM    <DIR>          .ipynb_checkpoints
# 04/05/2018  09:50 AM                 0 .Rhistory
# 12/21/2017  11:26 PM           269,813 01_Biogen Lab Mappings_Cindi.sql
# 04/09/2018  09:31 AM            13,194 02_Biogen Lymphocytes_Albatross_Cindi.sql
# 04/09/2018  11:01 AM            11,353 03_Biogen Lymphocytes Pelican_Cindi.sql
# 12/14/2017  04:51 PM            47,846 ALC_Cohort_SQL_code.SQL
# 11/22/2017  11:09 AM            65,566 Biogen_Lymphocyte_SQL_Code.sql
# 12/14/2017  04:51 PM            18,658 Continuous_Enrollment_Code.SQL
# 01/29/2018  12:13 PM    <DIR>          data
# 12/14/2017  04:51 PM            12,963 DMT_Cohort_SQL_code_v1.sql
# 04/03/2018  04:15 PM           373,971 example_data.csv
# 12/14/2017  04:51 PM             6,717 Multiple_Sclerosis_Cohort_SQL_code_v1.sql
# 04/04/2018  04:45 PM    <DIR>          out
# 11/29/2017  05:40 PM             1,438 Quick_Analysis_output.sql
# 12/14/2017  04:51 PM             1,420 README.md
# 03/22/2018  07:12 PM    <DIR>          ref
# 12/08/2017  04:09 PM               954 SFA.lnk
# 01/08/2018  05:40 PM            17,640 Spaghetti_Plot.do
# 01/12/2018  03:17 PM           776,426 Summary_Stats_01_R.html
# 04/06/2018  08:03 PM            27,556 Summary_Stats_01_R.Rmd
# 04/06/2018  08:03 PM            30,639 Summary_Stats_01_sql.sql
# 12/08/2017  05:03 PM             2,335 Tecfidera_ALC_Baseline_count.sql
# 12/14/2017  04:51 PM             7,524 Tecfidera_Cohort_SQL_code.sql
# 04/09/2018  10:59 AM           386,024 Tecfidera_Continuous_Enrollment.ipynb
# 04/09/2018  08:08 AM         5,664,477 Tec_cont_raw_final.xlsx
# 11/01/2017  03:11 PM                38 testtext.txt
# 03/22/2018  07:31 PM            10,066 Update_01_Create_Ref_table.ipynb
# 03/22/2018  07:43 PM             3,080 update_02_extract_Rx_claims.ipynb
#               25 File(s)      7,749,837 bytes
#                6 Dir(s)  17,669,451,776 bytes free
